# %%
import pandas as pd
import openpyxl
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
df_geo = pd.read_csv("C:/Users/Jeffs/Documents/Coding/Python/Portfolio/olist_ecommerce/olist_geolocation_dataset.csv")

# %%
df_geo.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
plt.figure(figsize=(10,10))
sns.countplot(x ='geolocation_state', data=df_geo, 
              order=df_geo['geolocation_state'].value_counts().sort_values().index, 
              palette='icefire_r')
# Out:
# <Axes: xlabel='geolocation_state', ylabel='count'>
